# %%
import cv2
import imutils
import matplotlib.pyplot as plt

# %%
# Cascade classifier will take haarcascade xml files as image kernel for detection

# %%
face_cascade = cv2.CascadeClassifier("/home/hadoop/haarcascade/haarcascade_frontalface_default.xml")
eye_cascade =  cv2.CascadeClassifier("/home/hadoop/haarcascade/haarcascade_eye.xml")
smile_cascade=  cv2.CascadeClassifier("/home/hadoop/haarcascade/haarcascade_smile.xml")

# %%
data_dir='/home/hadoop/data/photo'
pp_paths = [data_dir+"/"+f for f in os.listdir(data_dir)]
pp_paths
# Out:
# ['/home/hadoop/data/photo/parrot.jpg',
#  '/home/hadoop/data/photo/child.jpg',
#  '/home/hadoop/data/photo/pug.jpg',
#  '/home/hadoop/data/photo/male.jpg',
#  '/home/hadoop/data/photo/RBG-LED.jpg',
#  '/home/hadoop/data/photo/taylor-swift.png']

# %%
img= cv2.imread(pp_paths[-2])

#img = imutils.resize(img, width=700)

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)

# %%
for (x,y,w,h) in faces:
    # draw the rectangle on the face using coordinates
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2)
    # Face
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(gray, 1.3,5)
    for (ex, ey, ew, eh) in eyes:
        cv2.rectangle(img, (ex,ey), (ex+ew, ey+eh), (0,255,0), 2)

# %%
plt.imshow(img)

# %%
for (x, y, w, h) in faces:
        # draw the rectangle on the face using coordinates
        cv2.rectangle(img, (x, y), (x+w, y+h), (255,255,0), 2)
        # Face detection on gray
        roi_gray = gray[y:y+h, x:x+w]
        # Face detection with color image
        roi_color = img[y: y+h, x:x+w]  
        eyes = eye_cascade.detectMultiScale(gray, 1.3, 5)
        for (ex, ey, ew, eh) in eyes:
                # draw the rectangle on the face using coordinates
                cv2.rectangle(img, (ex, ey), (ex+ew, ey+eh), (255,255,255), 2)
                
plt.imshow(img)
